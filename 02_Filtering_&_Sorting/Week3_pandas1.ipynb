# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaratnida/DADS5001-Data-Analytics-and-Data-Science-Tools-and-Programming/blob/main/02_Filtering_%26_Sorting/Week3_pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
print(s)
print(type(s))
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64
# <class 'pandas.core.series.Series'>

# %%
dates = pd.date_range("20130101", periods=6)
print(dates)
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))
df
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
#                    A         B         C         D
# 2013-01-01 -0.117030 -0.330392  0.141827  2.193088
# 2013-01-02  0.136898 -1.527540 -0.622988  0.619967
# 2013-01-03 -2.425492 -0.968999  0.623577  0.495474
# 2013-01-04 -0.355056 -0.980402  0.180991 -0.707209
# 2013-01-05  0.704540  0.224774  0.306393 -1.466539
# 2013-01-06 -0.197816  0.382830  1.010758 -1.447307

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1.0, index=list(range(4))),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float64
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# 2. View

# %%
print(df.head())
print(df.tail(2))
print(df.index)
print(df.columns)
#print(df.describe())
print(df.sort_index(axis=1, ascending=False))
print(df.sort_values(by="B"))
# Out:
#                    A         B         C         D
# 2013-01-01 -0.117030 -0.330392  0.141827  2.193088
# 2013-01-02  0.136898 -1.527540 -0.622988  0.619967
# 2013-01-03 -2.425492 -0.968999  0.623577  0.495474
# 2013-01-04 -0.355056 -0.980402  0.180991 -0.707209
# 2013-01-05  0.704540  0.224774  0.306393 -1.466539
#                    A         B         C         D
# 2013-01-05  0.704540  0.224774  0.306393 -1.466539
# 2013-01-06 -0.197816  0.382830  1.010758 -1.447307
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')
# Index(['A', 'B', 'C', 'D'], dtype='object')
#                    D         C         B         A
# 2013-01-01  2.193088  0.141827 -0.330392 -0.117030
# 2013-01-02  0.619967 -0.622988 -1.527540  0.136898
# 2013-01-03  0.495474  0.623577 -0.968999 -2.425492
# 2013-01-04 -0.707209  0.180991 -0.980402 -0.355056
# ...

# %% [markdown]
# 3. Selecting

# %%
df.A
df["A"]
# Out:
# 2013-01-01   -0.117030
# 2013-01-02    0.136898
# 2013-01-03   -2.425492
# 2013-01-04   -0.355056
# 2013-01-05    0.704540
# 2013-01-06   -0.197816
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.117030 -0.330392  0.141827  2.193088
# 2013-01-02  0.136898 -1.527540 -0.622988  0.619967
# 2013-01-03 -2.425492 -0.968999  0.623577  0.495474

# %%
df.loc[dates[0]]
# Out:
# A   -0.117030
# B   -0.330392
# C    0.141827
# D    2.193088
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2013-01-01 -0.117030 -0.330392
# 2013-01-02  0.136898 -1.527540
# 2013-01-03 -2.425492 -0.968999
# 2013-01-04 -0.355056 -0.980402
# 2013-01-05  0.704540  0.224774
# 2013-01-06 -0.197816  0.382830

# %%
df.iloc[3]
# Out:
# A   -0.355056
# B   -0.980402
# C    0.180991
# D   -0.707209
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 2:4]
# Out:
#                    C         D
# 2013-01-04  0.180991 -0.707209
# 2013-01-05  0.306393 -1.466539

# %%
df[(df["A"] > 0) & (df["A"] < 1)]
# Out:
#                    A         B         C         D
# 2013-01-02  0.136898 -1.527540 -0.622988  0.619967
# 2013-01-05  0.704540  0.224774  0.306393 -1.466539

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN  0.141827  2.193088
# 2013-01-02  0.136898       NaN       NaN  0.619967
# 2013-01-03       NaN       NaN  0.623577  0.495474
# 2013-01-04       NaN       NaN  0.180991       NaN
# 2013-01-05  0.704540  0.224774  0.306393       NaN
# 2013-01-06       NaN  0.382830  1.010758       NaN

# %%
df2 = df.copy()
df2["E"] = ["one", "one", "two", "three", "four", "three"]
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -0.117030 -0.330392  0.141827  2.193088    one
# 2013-01-02  0.136898 -1.527540 -0.622988  0.619967    one
# 2013-01-03 -2.425492 -0.968999  0.623577  0.495474    two
# 2013-01-04 -0.355056 -0.980402  0.180991 -0.707209  three
# 2013-01-05  0.704540  0.224774  0.306393 -1.466539   four
# 2013-01-06 -0.197816  0.382830  1.010758 -1.447307  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03 -2.425492 -0.968999  0.623577  0.495474   two
# 2013-01-05  0.704540  0.224774  0.306393 -1.466539  four
