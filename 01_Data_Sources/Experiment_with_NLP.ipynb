# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaratnida/DADS5001-Data-Analytics-and-Data-Science-Tools-and-Programming/blob/main/01_Data_Sources/Experiment_with_NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Youtube

# %%
# !pip install pytchat #https://github.com/taizan-hokuto/pytchat/wiki
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytchat
#   Downloading pytchat-0.5.5-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 3.4 MB/s
# Collecting httpx[http2]
#   Downloading httpx-0.23.0-py3-none-any.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.9 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx[http2]->pytchat) (2022.9.24)
# Collecting httpcore<0.16.0,>=0.15.0
#   Downloading httpcore-0.15.0-py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 6.6 MB/s
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting h2<5,>=3
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 4.8 MB/s
# Collecting hyperframe<7,>=6.0
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Collecting anyio==3.*
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 8.2 MB/s
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 3.4 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from anyio==3.*->httpcore<0.16.0,>=0.15.0->httpx[http2]->pytchat) (4.1.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from anyio==3.*->httpcore<0.16.0,>=0.15.0->httpx[http2]->pytchat) (2.10)
# Installing collected packages: sniffio, rfc3986, h11, anyio, hyperframe, httpcore, hpack, httpx, h2, pytchat
# Successfully installed anyio-3.6.2 h11-0.12.0 h2-4.1.0 hpack-4.0.0 httpcore-0.15.0 httpx-0.23.0 hyperframe-6.0.1 pytchat-0.5.5 rfc3986-1.5.0 sniffio-1.3.0

# %%
# !pip install --upgrade pythainlp
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pythainlp
#   Downloading pythainlp-3.1.0-py3-none-any.whl (9.6 MB)
#      |████████████████████████████████| 9.6 MB 5.3 MB/s
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.7/dist-packages (from pythainlp) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.22.0->pythainlp) (2.10)
# Installing collected packages: pythainlp
# Successfully installed pythainlp-3.1.0

# %%
# !pip install nlpo3
# !pip install transformers sentencepiece

# %%
from pythainlp.wangchanberta import ThaiNameTagger, pos_tag
from nlpo3 import segment
t = ThaiNameTagger(dataset_name="thainer")
# Out:
# Downloading:   0%|          | 0.00/905k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/282 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/546 [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/pythainlp/wangchanberta/postag.py:31: UserWarning:
#             LST20 corpus are free for research and open source only.
#
#             If you want to use in Commercial use, please contract NECTEC.
#
#             https://www.facebook.com/dancearmy/posts/10157641945708284
#
#   """)
# Downloading:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/419M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/pipelines/token_classification.py:136: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="none"` instead.
#   "`grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to"
# Downloading:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/419M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/pipelines/token_classification.py:136: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   "`grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to"

# %%
import pytchat

chat = pytchat.create(video_id="ZB7zAh9yqi8")

while chat.is_alive():
  for c in chat.get().sync_items():
    #print(dir(c))
    print(f"{c.datetime} [{c.author.name}]- {c.message} -> {t.get_ner(c.message,tag=False)}")
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# 2022-10-24 13:44:00 [BANK P.]- พี่พูดถึงจังหวะแรกที่ฮาแลนด์โดนทำฟาว์หน่อยคับไม่ได้จุดโทษได้ยังไง -> [('พี่พูดถึงจังหวะแรกที่', 'O'), ('ฮา', 'B-PERSON'), ('แลนด์', 'I-PERSON'), ('โดนทําฟาว์หน่อยคับไม่ได้จุดโทษได้ยังไง', 'O')]
# 2022-10-24 13:44:36 [มะแขว่น]- โดนไบร์ตันกดช่วงที่ Lampteyลง พักหนึ่งจากนั้ซิตี้เข้าเกมส์ตัวเองได้ -> [('โดน', 'O'), ('ไบ', 'B-ORGANIZATION'), ('ร์', 'I-ORGANIZATION'), ('ตัน', 'I-ORGANIZATION'), ('กดช่วงที่ ', 'O'), ('', 'B-PERSON'), (' ⁇ ', 'I-PERSON'), ('amp', 'B-ORGANIZATION'), ('te', 'I-ORGANIZATION'), ('y', 'I-ORGANIZATION'), ('ลง  พักหนึ่งจากนั้ซิตี้เข้าเกมส์ตัวเองได้', 'O')]
# 2022-10-24 13:44:56 [𒆜𝙋𝙀𝙉𒆜◡̈⃝︎🤍]- :hugging_face::hugging_face::hugging_face: -> [(':hugging_face::hugging_face::hugging_face:', 'O')]
# 2022-10-24 13:45:14 [CRYPTO HUNTER]- ทําไม Pep ถึงถอด HAALAND ออกยิงไป 2 ลูกน่าจะปล่อยให้ยิง Hattrick -> [('ทําไม ', 'O'), ('', 'B-ORGANIZATION'), (' ⁇ ', 'I-ORGANIZATION'), ('ep', 'I-ORGANIZATION'), ('  ถึงถอด ', 'O'), ('', 'B-ORGANIZATION'), (' ⁇ ', 'I-ORGANIZATION'), ('  ออกยิงไป  2  ลูกน่าจะปล่อยให้ยิง   ⁇ attrick', 'O')]

# %%
import pytchat
import pandas as pd 
chat = pytchat.create(video_id="ZB7zAh9yqi8")

dList = []
aList = []
mList = []

i = 0
while chat.is_alive():
  for c in chat.get().sync_items():
    print(f"{c.datetime} [{c.author.name}]- {c.message}")
    dList.append(c.datetime)
    aList.append(c.author.name)
    mList.append(c.message)
    i = i+1
    if i == 10:
      chat.terminate()
      break

# dictionary of lists 
dict = {'dateTime': dList, 'authorName': aList, 'Message': mList}

df = pd.DataFrame(dict)
df.head()

from google.colab import files
df.to_csv("data.csv", encoding="utf_8_sig", index=False) #cp874, #TIS-620
files.download("data.csv")
# Out:
# 2022-10-11 13:11:02 [elghazi]- มาาาา
# 2022-10-11 13:11:07 [ชาวประมงระยา]- ละดูหน้า
# 2022-10-11 13:11:21 [ohpreams ‘94]- มาาาาาาาาาา
# 2022-10-11 13:11:24 [sunchai sunchaisuwon]- มีคนติดโอเวอร์วอทททททท2
# 2022-10-11 13:11:30 [Wanitch Teeraphothipan]- มาาาาา
# 2022-10-11 13:11:31 [Tachporn Sirithamrak]- มาาาา
# 2022-10-11 13:11:32 [hiimpiyachat]- มาเฉยยย
# 2022-10-11 13:11:35 [Aom ที่ไม่มีไรดีเลย]- มาค้าบบบบบลุยยยยค้าบบบบบบ
# 2022-10-11 13:11:45 [XEAR]- รอออ
# 2022-10-11 13:11:47 [Gg]- มาาาาาาาาาาาาาาาาาาาาาาาาา

# %% [markdown]
# # 2. Twitter
# #### Reference https://developer.twitter.com/en/docs/twitter-api/v1/tweets/timelines/api-reference/get-statuses-user_timeline

# %%
# !pip install tweepy #https://www.tweepy.org/
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tweepy in /usr/local/lib/python3.7/dist-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.3.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy) (3.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)

# %% [markdown]
# ### Setup key and secret

# %%
from getpass import getpass
consumer_key = getpass('Enter the consumer_key: ')
consumer_secret = getpass('Enter the consumer_secret: ')
access_token = getpass('Enter the access_token: ')
access_token_secret = getpass('Enter the access_token_secret: ')

# %% [markdown]
# ### Streaming

# %%
import tweepy

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# %% [markdown]
# ### Example 1: User home timeline

# %%
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
    print("----------------------------------")

# %% [markdown]
# ### Example 2: monitor user ID

# %%
import pandas as pd
dList = []
aList = []
mList = []
userID = "elonmusk"
user = api.get_user(userID)

tweets = api.user_timeline(screen_name=userID, 
                           # 10 is the maximum allowed count
                           count=10,
                           include_rts = False,
                           # Necessary to keep full_text 
                           # otherwise only the first 140 words are extracted
                           tweet_mode = 'extended'
                           )

for info in tweets[:5]:
    #print(info)
    #print("ID: {}".format(info.id))
    print(info.created_at)
    print(info.full_text)
    print("\n")
    dList.append(info.id)
    aList.append(info.created_at)
    mList.append(info.full_text.encode().decode('unicode_escape'))

dict = {'id': dList, 'time': aList, 'text': mList}

df = pd.DataFrame(dict)
df.head()

from google.colab import files
df.to_csv("data.csv", encoding="ISO-8859-1", index=False)
files.download("data.csv")

# %% [markdown]
# ### Web scraping

# %%
import requests #connect url
from bs4 import BeautifulSoup #https://www.crummy.com/software/BeautifulSoup/bs4/doc/

url = requests.get('https://www.blognone.com/node/109731')
#print("url = ",url)

soup = BeautifulSoup(url.content, 'html.parser')
#print("soup = ",soup)

#data = soup.find(itemprop='name')
#print(data)

####
data = ''
idx = 1
for i in soup.find_all("div", {"class": "field-item even"}):
  output = i.find("p")
  #print(type(output))
  if output != None:
    print(idx, " = ", output.text)
    idx = idx + 1
